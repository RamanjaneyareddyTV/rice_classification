# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("riceClassification.csv")

# %%
data.head()
# Out:
#    id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0   1  4537        92.229316        64.012769      0.719916        4677
# 1   2  2872        74.691881        51.400454      0.725553        3015
# 2   3  3048        76.293164        52.043491      0.731211        3132
# 3   4  3073        77.033628        51.928487      0.738639        3157
# 4   5  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
data.isnull().sum()
# Out:
# id                 0
# Area               0
# MajorAxisLength    0
# MinorAxisLength    0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Perimeter          0
# Roundness          0
# AspectRation       0
# Class              0
# dtype: int64

# %%
data['Class'].value_counts()
# Out:
# 1    9985
# 0    8200
# Name: Class, dtype: int64

# %%
X=data.drop(['Class'],axis=1)
X
# Out:
#           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 0          1  4537        92.229316        64.012769      0.719916
# 1          2  2872        74.691881        51.400454      0.725553
# 2          3  3048        76.293164        52.043491      0.731211
# 3          4  3073        77.033628        51.928487      0.738639
# 4          5  3693        85.124785        56.374021      0.749282
# ...      ...   ...              ...              ...           ...
# 18180  18181  5853       148.624571        51.029281      0.939210
# 18181  18182  7585       169.593996        58.141659      0.939398
# 18182  18183  6365       154.777085        52.908085      0.939760
# 18183  18184  5960       151.397924        51.474600      0.940427
# 18184  18185  6134       153.081981        51.590606      0.941500
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  AspectRation
# 0            4677      76.004525  0.657536    273.085   0.764510      1.440796
# 1            3015      60.471018  0.713009    208.317   0.831658      1.453137
# 2            3132      62.296341  0.759153    210.012   0.868434      1.465950
# 3            3157      62.551300  0.783529    210.657   0.870203      1.483456
# 4            3802      68.571668  0.769375    230.332   0.874743      1.510000
# ...           ...            ...       ...        ...        ...           ...
# 18180        6008      86.326537  0.498594    332.960   0.663444      2.912535
# 18181        7806      98.272692  0.647461    385.506   0.641362      2.916910
# 18182        6531      90.023162  0.561287    342.253   0.682832      2.925396
# 18183        6189      87.112041  0.492399    343.371   0.635227      2.941216
# 18184        6283      88.374495  0.489975    338.613   0.672274      2.967245
#
# [18185 rows x 11 columns]

# %%
y=data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 50)

# %%
X_train
# Out:
#           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 17888  17889  7317       151.494482        62.294627      0.911545
# 12733  12734  8679       155.765218        72.208540      0.886059
# 10224  10225  5060       148.507426        44.298270      0.954475
# 16835  16836  8914       163.637941        70.808530      0.901531
# 10432  10433  6266       128.962259        62.299511      0.875574
# ...      ...   ...              ...              ...           ...
# 14565  14566  7224       143.388681        64.641489      0.892618
# 15649  15650  8521       157.162587        69.675873      0.896355
# 10123  10124  6002       161.674485        48.472825      0.953997
# 5600    5601  6144       153.944288        51.936256      0.941372
# 14000  14001  9126       160.820294        73.108084      0.890698
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  AspectRation
# 17888        7529      96.520950  0.659189    354.261   0.732649      2.431903
# 12733        8956     105.121102  0.788642    374.688   0.776855      2.157158
# 10224        5191      80.265759  0.451222    323.912   0.606047      3.352443
# 16835        9165     106.534770  0.539915    387.200   0.747157      2.310992
# 10432        6350      89.320317  0.808829    307.096   0.834934      2.070036
# ...           ...            ...       ...        ...        ...           ...
# 14565        7343      95.905591  0.654407    337.722   0.795919      2.218214
# 15649        8707     104.159849  0.566971    371.550   0.775650      2.255624
# 10123        6260      87.418441  0.489400    367.851   0.557394      3.335363
# 5600         6312      88.446502  0.673684    345.403   0.647156      2.964101
# 14000        9360     107.794175  0.592290    383.184   0.781044      2.199761
#
# [14548 rows x 11 columns]

# %%
X_test
# Out:
#           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 15900  15901  7769       150.240657        66.314697      0.897315
# 4057    4058  5954       149.133007        51.974002      0.937306
# 8008    8009  6471       162.121713        52.097412      0.946961
# 3975    3976  5452       142.772899        49.829847      0.937117
# 9715    9716  6207       162.612661        49.641688      0.952264
# ...      ...   ...              ...              ...           ...
# 13622  13623  8534       155.384680        71.015215      0.889452
# 7109    7110  5019       141.314601        46.309985      0.944779
# 14499  14500  8522       156.110819        70.454306      0.892367
# 1974    1975  5448       138.971398        50.930427      0.930425
# 4660    4661  5072       138.210901        47.569421      0.938904
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  AspectRation
# 15900        7899      99.457519  0.691684    351.913   0.788323      2.265571
# 4057         6099      87.068182  0.497410    334.680   0.667973      2.869377
# 8008         6661      90.769671  0.549741    356.701   0.639106      3.111896
# 3975         5600      83.316877  0.557350    320.817   0.665658      2.865208
# 9715         6389      88.898807  0.548079    358.562   0.606685      3.275728
# ...           ...            ...       ...        ...        ...           ...
# 13622        8829     104.239274  0.646515    374.358   0.765223      2.188048
# 7109         5166      79.939910  0.531505    313.722   0.640822      3.051493
# 14499        8749     104.165961  0.572946    372.784   0.770614      2.215774
# 1974         5637      83.286308  0.534589    318.403   0.675294      2.728652
# 4660         5204      80.360880  0.488915    307.612   0.673570      2.905457
#
# [3637 rows x 11 columns]

# %%
y_train
# Out:
# 17888    0
# 12733    0
# 10224    1
# 16835    0
# 10432    0
#         ..
# 14565    0
# 15649    0
# 10123    1
# 5600     1
# 14000    0
# Name: Class, Length: 14548, dtype: int64

# %%
y_test
# Out:
# 15900    0
# 4057     1
# 8008     1
# 3975     1
# 9715     1
#         ..
# 13622    0
# 7109     1
# 14499    0
# 1974     1
# 4660     1
# Name: Class, Length: 3637, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', random_state = 51)
rf_classifier.fit(X_train, y_train)
y_pred_rf = rf_classifier.predict(X_test)
accuracy_score(y_test, y_pred_rf)
# Out:
# 1.0

# %%
cm = confusion_matrix(y_test, y_pred_rf)
plt.title('Heatmap of Confusion Matrix', fontsize = 70)
sns.heatmap(cm, annot = True)
plt.show()

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1627
#            1       1.00      1.00      1.00      2010
#
#     accuracy                           1.00      3637
#    macro avg       1.00      1.00      1.00      3637
# weighted avg       1.00      1.00      1.00      3637
